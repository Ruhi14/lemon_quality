# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/ruhi/.local/lib/python3.10/site-packages (2.17.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (1.65.1)
# Requirement already satisfied: h5py>=3.10.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (4.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: packaging in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (24.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: keras>=3.2.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: namex in /home/ruhi/.local/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: rich in /home/ruhi/.local/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: optree in /home/ruhi/.local/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (2020.6.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ruhi/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ruhi/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ruhi/.local/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ruhi/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ruhi/.local/lib/python3.10/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ruhi/.local/lib/python3.10/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ruhi/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlip in /home/ruhi/.local/lib/python3.10/site-packages (0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/ruhi/.local/lib/python3.10/site-packages (3.4.1)
# Requirement already satisfied: namex in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (3.11.0)
# Requirement already satisfied: rich in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (13.7.1)
# Requirement already satisfied: packaging in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (24.0)
# Requirement already satisfied: optree in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (0.4.0)
# Requirement already satisfied: absl-py in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /home/ruhi/.local/lib/python3.10/site-packages (from keras) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ruhi/.local/lib/python3.10/site-packages (from optree->keras) (4.10.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ruhi/.local/lib/python3.10/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ruhi/.local/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ruhi/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'lemon_dataset',
    seed = 123,
    shuffle = True,
    batch_size = 32,
    image_size = (300,300)
)
# Out:
# Found 2528 files belonging to 3 classes.

# %%
dataset
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
class_name = dataset.class_names
class_name
# Out:
# ['bad_quality', 'empty_background', 'good_quality']

# %%
for image_batch, label_batch in dataset.take(1):
    print(image_batch.shape)
    print(label_batch.numpy())
# Out:
# (32, 300, 300, 3)
# [0 0 2 2 2 1 0 2 1 0 2 2 2 0 2 2 2 2 0 2 0 1 2 2 2 1 2 2 2 2 0 2]
# 2024-07-28 23:23:49.959282: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
len(dataset)
# Out:
# 79

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(class_name[label_batch[i]])
        plt.axis('off')
# Out:
# 2024-07-28 23:23:50.120729: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
79 * .8
# Out:
# 63.2

# %%
dataset.take(63)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 300, 300, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
def split_dataset(dataset, train_split = .8, test_split = .1, val_split = .1, shuffle = True, shuffle_size = 10000):
    assert(train_split + test_split + val_split) == 1
    ds_size = len(dataset)
    if shuffle:
        dataset = dataset.shuffle(shuffle_size, seed = 12)
    train_size = int(ds_size * train_split)
    test_size = int(ds_size * test_split)
    val_size = int(ds_size * val_split)


    train_ds = dataset.take(train_size)
    test_ds = dataset.skip(train_size).skip(val_size)
    val_ds = dataset.skip(train_size).take(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = split_dataset(dataset)

# %%
len(train_ds)
# Out:
# 63

# %%
len(test_ds)
# Out:
# 9

# %%
len(val_ds)
# Out:
# 7

# %% [markdown]
# ### cache, shuffle prefetch the dataset

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# ### model building

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(300, 300),
    layers.Rescaling(1./299)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip('horizontal_and_vertical'),
    layers.RandomRotation(0.2)
])

# %% [markdown]
# ### apply data augmentation in train ds

# %%
train_ds = train_ds.map(
    lambda x, y:(data_augmentation(x, training=True), y)
).prefetch(buffer_size = tf.data.AUTOTUNE)

# %% [markdown]
# ### data model architecture

# %%
channel = 3

# %%
input_shape = (32, 300, 300, channel)

# %%
model = models.Sequential([
    resize_and_rescale,
    layers.Conv2D(32, kernel_size = (3,3), activation = 'relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size = (3,3), activation = 'relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation = 'relu'),
    layers.Dense(64, activation = 'softmax')
    
])
# Out:
# /home/ruhi/.local/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.build(input_shape = input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (32, 300, 300, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (32, 298, 298, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 149, 149, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 147, 147, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 73, 73, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (32, 71, 71, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (32, 35, 35, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (32, 33, 33, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (32, 16, 16, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (32, 14, 14, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (32, 7, 7, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 3136)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 64)               │       200,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 64)               │         4,160 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 335,104 (1.28 MB)
#  Trainable params: 335,104 (1.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### compile our Model

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size = 32,
    validation_data = val_ds,
    verbose = 1,
    epochs = 30
)
# Out:
# Epoch 1/30
# 2024-07-28 23:23:54.860036: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 34560128 bytes after encountering the first element of size 34560128 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-07-28 23:23:55.340662: W tensorflow/core/kernels/data/prefetch_autotuner.cc:52] Prefetch autotuner tried to allocate 34560128 bytes after encountering the first element of size 34560128 bytes.This already causes the autotune ram budget to be exceeded. To stay within the ram budget, either increase the ram budget or reduce element size
# 2024-07-28 23:23:55.381357: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 363741184 exceeds 10% of free system memory.
# 2024-07-28 23:23:56.017369: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 90935296 exceeds 10% of free system memory.
# 2024-07-28 23:23:56.099090: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 177020928 exceeds 10% of free system memory.
# 2024-07-28 23:23:56.410722: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 43655168 exceeds 10% of free system memory.
# 2024-07-28 23:23:56.439278: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 41295872 exceeds 10% of free system memory.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 164s 3s/step - accuracy: 0.3940 - loss: 1.7975 - val_accuracy: 0.8259 - val_loss: 0.4064
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.8326 - loss: 0.4062 - val_accuracy: 0.8393 - val_loss: 0.3904
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 158s 3s/step - accuracy: 0.8283 - loss: 0.3976 - val_accuracy: 0.8438 - val_loss: 0.3457
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 158s 3s/step - accuracy: 0.8451 - loss: 0.3563 - val_accuracy: 0.8750 - val_loss: 0.3364
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - accuracy: 0.8497 - loss: 0.3397 - val_accuracy: 0.9107 - val_loss: 0.2335
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9114 - loss: 0.2358 - val_accuracy: 0.9643 - val_loss: 0.1369
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.9202 - loss: 0.1897 - val_accuracy: 0.9509 - val_loss: 0.1208
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9386 - loss: 0.1723 - val_accuracy: 0.9241 - val_loss: 0.1584
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.9354 - loss: 0.1445 - val_accuracy: 0.9732 - val_loss: 0.0678
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9559 - loss: 0.1227 - val_accuracy: 0.9420 - val_loss: 0.1425
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9589 - loss: 0.1073 - val_accuracy: 0.9821 - val_loss: 0.0516
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.9734 - loss: 0.0754 - val_accuracy: 0.9688 - val_loss: 0.0589
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9696 - loss: 0.0640 - val_accuracy: 0.9509 - val_loss: 0.1594
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9786 - loss: 0.0451 - val_accuracy: 0.9821 - val_loss: 0.0475
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 155s 2s/step - accuracy: 0.9701 - loss: 0.0626 - val_accuracy: 0.9777 - val_loss: 0.0571
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9785 - loss: 0.0632 - val_accuracy: 0.9688 - val_loss: 0.0808
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9740 - loss: 0.0753 - val_accuracy: 0.9598 - val_loss: 0.1078
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 163s 3s/step - accuracy: 0.9711 - loss: 0.0753 - val_accuracy: 0.9688 - val_loss: 0.0646
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 160s 3s/step - accuracy: 0.9754 - loss: 0.0551 - val_accuracy: 0.9732 - val_loss: 0.1008
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 162s 3s/step - accuracy: 0.9859 - loss: 0.0497 - val_accuracy: 0.9777 - val_loss: 0.0457
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 160s 3s/step - accuracy: 0.9901 - loss: 0.0271 - val_accuracy: 0.9866 - val_loss: 0.0262
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9817 - loss: 0.0519 - val_accuracy: 0.9732 - val_loss: 0.0477
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9861 - loss: 0.0526 - val_accuracy: 0.9732 - val_loss: 0.0748
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9792 - loss: 0.0532 - val_accuracy: 0.9777 - val_loss: 0.0636
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 159s 3s/step - accuracy: 0.9857 - loss: 0.0322 - val_accuracy: 0.9732 - val_loss: 0.0724
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9827 - loss: 0.0627 - val_accuracy: 0.9688 - val_loss: 0.0704
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 163s 3s/step - accuracy: 0.9839 - loss: 0.0434 - val_accuracy: 0.9732 - val_loss: 0.0516
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - accuracy: 0.9815 - loss: 0.0394 - val_accuracy: 0.9866 - val_loss: 0.0346
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9888 - loss: 0.0274 - val_accuracy: 0.9688 - val_loss: 0.0719
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 158s 3s/step - accuracy: 0.9807 - loss: 0.0356 - val_accuracy: 0.9688 - val_loss: 0.0402

# %%
scores = model.evaluate(test_ds)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 509ms/step - accuracy: 0.9979 - loss: 0.0092

# %%
scores
# Out:
# [0.013952244073152542, 0.9965277910232544]

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
epochs = 30

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize = (8,8))
plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label = 'Training Accuracy')
plt.plot(range(epochs), val_acc, label = 'Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Traing and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label = 'Training Loss')
plt.plot(range(epochs), val_loss, label = 'Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()

    print('first image to predict')
    plt.imshow(first_image)
    plt.show()

    print('Actual Label', class_names[first_label])
    predict_image = model.predict(images_batch)
    predict_label = np.argmax(predict_image[0])

    print(predict_label)
    print('Predicted Label', class_name[predicted_label])
# Out:
# first image to predict
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 9
#       6 plt.imshow(first_image)
#       7 plt.show()
# ----> 9 print('Actual Label', class_names[first_label])
#      10 predict_image = model.predict(images_batch)
#      11 predict_label = np.argmax(predict_image[0])
#
# NameError: name 'class_names' is not defined
